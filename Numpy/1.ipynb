# %%
import numpy as np
print(np.__version__)
# Out:
# 2.3.5

# %%
# my_list=[1,2,3,4]
# my_list=my_list*2
# print(my_list)
# this is basic list in oython
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]

# %%
# This is numpy array which simplifies the usage of list
arr=np.array([1,2,3,4])
print(type(arr))
# Out:
# <class 'numpy.ndarray'>

# %%
arr=arr*2
print(arr)
# Out:
# [2 4 6 8]
