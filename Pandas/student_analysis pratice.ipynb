# %%
import pandas as pd
Students=pd.DataFrame({
    "Name":["A","B","C","D"],
    "Marks":[75,90,60,85],
    "Attendance":[90,95,80,88]
})
min=Students["Marks"].min()
print(min)
# Out:
# 60

# %%
avg=Students["Marks"].mean()
print(avg)
# Out:
# 77.5

# %%
sort=Students.sort_values("Marks")
print(sort)
# Out:
#   Name  Marks  Attendance
# 2    C     60          80
# 0    A     75          90
# 3    D     85          88
# 1    B     90          95

# %%
Students["Grade"]= ["B", "A", "C", "B"]
print(Students)
# Out:
#   Name  Marks  Attendance Grade
# 0    A     75          90     B
# 1    B     90          95     A
# 2    C     60          80     C
# 3    D     85          88     B
