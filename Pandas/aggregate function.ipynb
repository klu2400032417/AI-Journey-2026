# %%
# aggregrate functions= reduces a set of values into a single summary value
# Used to summarise and analyze data often  used with the groupby() function
import pandas as pd
df=pd.read_csv("train.csv")
print(df.mean(numeric_only=True))
# telling find mean for the col which has all the col with numeric values only
# Out:
# s13       0.983123
# s48       0.433338
# s56            NaN
# s57            NaN
# s59            NaN
# n1       10.201863
# n2        1.600111
# n3        4.805099
# n4        5.080537
# n5      -32.641183
# n6        0.015014
# n7       -9.107429
# n8        1.612428
# n9        5.232644
# n10       6.115109
# n11       1.699553
# n12       0.009992
# n13       0.089506
# n14       0.497570
# n15       2.997740
# label     0.168067
# dtype: float64

# %%
this type of aggergate function is for whole dataset
# print(df.min(numeric_only=True))
# print(df.max(numeric_only=True))
# print(df.sum(numeric_only=True))
print(df.count())
# Out:
# id        28322
# gender    28322
# s11       28322
# s12       28322
# s13       28322
# s16       28322
# s17       28322
# s18       28322
# s48       28322
# s52       28322
# s53       28322
# s54        2628
# s55        3206
# s56           0
# s57           0
# s58       28322
# s59           0
# s69       28322
# s70       28322
# s71       28322
# n1        28322
# n2        28322
# n3        28322
# n4        28322
# n5        28322
# n6        28322
# n7        28322
# n8        28322
# n9        28322
# n10       28322
# n11       28322
# n12       28322
# n13       28322
# n14       28322
# n15       28322
# label     28322
# dtype: int64

# %%
#  for for single col we need to apply aggregate funtions means
print(df["s13"].min())
print(df["s12"].max())
# Out:
# 0
# Y

# %%
group=df.groupby("s13")
# this will group thesame value in s13 col into grp
#  
print(group["s11"].mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1944, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1943 try:
# -> 1944     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1945 except Exception as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:873, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     871     preserve_dtype = True
# --> 873 result = self._aggregate_series_pure_python(obj, func)
#     875 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:894, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     893 for i, group in enumerate(splitter):
# --> 894     res = func(group)
#     895     res = extract_result(res)
#
# ...
