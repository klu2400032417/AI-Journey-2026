# %%
import pandas as pd
# importing csv and json files 
df=pd.read_csv("train.csv")
print(df)
# to print all the data
# print(df.to_string())
# Out:
#                                                       id gender s11 s12  s13  \
# 0      b'gAAAAABinOicS09vrmgh0_JyEHihI13ptO0rCyHP7l76...      M   Y   N    1
# 1      b'gAAAAABinOiWGC1WhR6WYP0DA5ssGv9rIekrWUwCdJ8F...      M   Y   Y    1
# 2      b'gAAAAABinOibTcOBFIVeA4nVF3FuFz_QX3ZlPPFc21gS...      M   Y   Y    1
# 3      b'gAAAAABinOig-g3-Q1ggjlMhfUSdn21Aj5yVVeVvXbis...      F   Y   Y    1
# 4      b'gAAAAABinOiXdoaNUzihOSbyY1tjWtd5EgMaXkkvH6SV...      M   N   Y    1
# ...                                                  ...    ...  ..  ..  ...
# 28317  b'gAAAAABinOiX2ss5U2ZT5zFd8zf7HcBDWPvbivNz5wAy...      M   Y   Y    1
# 28318  b'gAAAAABinOiabmEADrCTZQktCKiahJkR_0kDa_8WOlos...      M   Y   Y    1
# 28319  b'gAAAAABinOicscC37w1W9uiIlYL1U5D_mUtmgdUg8QTl...      F   Y   Y    1
# 28320  b'gAAAAABinOib-JZ8iQDxjSRsa1dPT1TqeSQ_si4mAw5f...      M   Y   Y    1
# 28321  b'gAAAAABinOiZ3mCQAtoJFXj-Ymjhi9FbbZ_Ypi5gDoAE...      M   Y   Y    1
#
# ...

# %%
# df=pd.read_json("")

# %%
# selection by column
print(df["gender"])
# to print everyh value
# print(df["gender"].to_string())
# Out:
# 0        M
# 1        M
# 2        M
# 3        F
# 4        M
#         ..
# 28317    M
# 28318    M
# 28319    F
# 28320    M
# 28321    M
# Name: gender, Length: 28322, dtype: object

# %%
# selection by row
print(df.loc[0])
# if u want to mention the index_col u can while reading
# like this df=pd.read_csv("train.csv",index_col="Name") then 
# u can write print(df.loc["train_name"]) then we will get the details of that name
# Out:
# id        b'gAAAAABinOicS09vrmgh0_JyEHihI13ptO0rCyHP7l76...
# gender                                                    M
# s11                                                       Y
# s12                                                       N
# s13                                                       1
# s16                                                       D
# s17                                                       D
# s18                                                       B
# s48                                                       0
# s52                                                       1
# s53
# s54                                                     NaN
# s55                                                      kK
# s56                                                     NaN
# s57                                                     NaN
# s58                                                       B
# s59                                                     NaN
# ...

# %%
print(df.iloc[0:5])
# Out:
#                                                   id gender s11 s12  s13 s16  \
# 0  b'gAAAAABinOicS09vrmgh0_JyEHihI13ptO0rCyHP7l76...      M   Y   N    1   D
#
#   s17 s18  s48 s52  ...        n7        n8        n9       n10       n11 n12  \
# 0   D   B    0   1  ... -9.126056  1.732291  3.698504  4.804517  1.544484   0
#
#    n13      n14 n15 label
# 0    0  0.63122   5     0
#
# [1 rows x 36 columns]

# %%
print(df.iloc[0:5,1:3])
# prints 0 to 4 rows and only 3col from every  row
# Out:
#   gender s11
# 0      M   Y
# 1      M   Y
# 2      M   Y
# 3      F   Y
# 4      M   N
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 28317    True
# 28318    True
# 28319    True
# 28320    True
# 28321    True
# Name: s13, Length: 28322, dtype: bool
