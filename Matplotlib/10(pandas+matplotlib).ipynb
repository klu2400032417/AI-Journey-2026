# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as  pd
df=pd.read_csv("train.csv")
type_count=df["s11"].value_counts(ascending=True)
plt.bar(type_count.index,type_count.values,color="yellow",edgecolor="black")
plt.title("About t
plt.show()
