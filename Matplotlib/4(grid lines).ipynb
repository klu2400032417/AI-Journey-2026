# %%
import matplotlib.pyplot as plt
import numpy as np
# grid()= helps make plots easier to read by adding reference lines.

x=np.array([1,2,3,4,5])
y=np.array([5,10,15,20,25])
#  we will get gri lines has graphs sheet
plt.grid(linewidth=2,color="lightgrey",linestyle="d)
# plt.grid(axis="x") we will get lines on x axis means parllel to y axis
# plt.grid(axis="y")
plt.plot(x,y)
plt.show()
