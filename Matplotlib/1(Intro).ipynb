# %%
# matplotlib =is used to represent inthe form of plots or graphs(line grqphs , bar graphs or scatter plots , histograms , pie charts)
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.10.6

# %%
# pyplot is a library under matplotlib 
#  pyplot provides a user freindly interface for plotting
import matplotlib.pyplot as plt

x=[2023,2024,2025,2026]
y=[15,25,30,20]
plt.plot(x,y)
plt.show()

# %%
import numpy as np
# numpy array is faster than list and providesmany methods
x=np.array([2023,2024,2025,2026])
y=np.array([15,25,30,20])
