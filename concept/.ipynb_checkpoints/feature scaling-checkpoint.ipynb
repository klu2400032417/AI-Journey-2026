# %%
Feature Scaling in Machine Learning

Feature scaling is a preprocessing step that transforms features to a similar scale, ensuring all variables contribute equally to a model. It is crucial for algorithms sensitive to feature magnitude, such as gradient descent-based models (Linear/Logistic Regression, Neural Networks), and distance-based models (KNN, SVM, K-Means) . Tree-based models like Decision Trees or Random Forests are generally unaffected by scaling.

Common Scaling Techniques:

Absolute Maximum Scaling Divides each value by the maximum absolute value of the feature, mapping values to [-1, 1].

max_abs = np.max(np.abs(df), axis=0)
scaled_df = df / max_abs

Min-Max Scaling (Normalization) Rescales features to a fixed range, usually [0, 1].

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaled_df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

Vector Normalization Scales each sample (row) to have unit norm (length = 1).

from sklearn.preprocessing import Normalizer
scaler = Normalizer()
scaled_df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

Standardization (Z-score) Centers features to mean 0 and variance 1.

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

Robust Scaling Uses median and IQR, making it robust to outliers.

from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()
scaled_df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

Best Practices:

Fit on training data only, then transform both train and test sets to avoid data leakage .

Choose scaling based on algorithm: Gradient descent models: Standardization or Min-Max. Distance-based models: Scaling is essential. Tree-based models: Scaling not required.

For PCA, scaling ensures all features contribute equally to variance .

Example: Standardizing Before KNN

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import pandas as pd

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, y_train)
print("Accuracy:", accuracy_score(y_test, knn.predict(X_test_scaled)))
Copy
Scaling can drastically improve accuracy for sensitive algorithms, as shown in KNN and SVM experiments .
